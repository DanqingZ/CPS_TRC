# %%
cd ../
# Out:
# /Users/danqing0703/Google_Drive/research_2017Spring/code_review/CPS_TRC

# %%
# %load_ext autoreload
# %autoreload 2
from src.models.cplex_final import cplex_CPS
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# select 600 people for visualization
X = np.loadtxt('notebook/data/x.csv')
Y = np.loadtxt('notebook/data/y.csv')
X = X[0:600]
Y = Y[0:600]

# %%
# filepath and filename shall be changed to run the code
filepath = '/Users/danqing0703/Google_Drive/research_2017Spring/code_review/CPS_TRC/output/cplex'
filename = 'cplex_run_1.csv'

# %%
A = cplex_CPS(X, Y, filepath, filename)

# %%
A.run()
# Out:
# ............
# Number of peole for assignment
# 300
# Number of potential social center
# 300
# ............
# Number of peole for assignment
# 300
# Number of potential social center
# 300

# %%
community = A.DF['C'].tolist()
X = A.DF['X'].tolist()
Y = A.DF['Y'].tolist()
plt.figure(3,figsize=(12,8)) 
plt.scatter(X,Y,c=community,s=50)
plt.title('location visualization',fontsize =30)
plt.show()
